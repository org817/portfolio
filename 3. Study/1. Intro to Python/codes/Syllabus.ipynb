# %% [markdown]
# # Syllabus
#
# --------------
#
# # Course contents
# |    날짜    | 회차 |              내용             | assignment |
# |:----------:|:----:|:-----------------------------:|:----------:|
# | 2017-04-03 |   1  | Introduction                  |            |
# | 2017-04-10 |   2  | Python 기초 - 1               |            |
# | 2017-04-17 |   3  | Python 기초 - 2               |            |
# | 2017-04-24 |   4  | 클래스와 객체                  |            |
# | 2017-05-01 |   5  | 데이터분석 - 1 Numpy           |            |
# | 2017-05-08 |   6  | 데이터분석 - 2 Pandas(1)       |            |
# | 2017-05-15 |   7  | 데이터분석 - 3 Pandas(2)       |            |
# | 2017-05-23 |   8  | 데이터분석 - 4 Pandas(3)       |            |
# | 2017-05-30 |   9  | 데이터분석 - 5 Matplotlib, 크롤링 기초 |            |
# | 2017-06-?? |  10  | Final Project                 |      .     |
#
#
# ----------------
# # 세부 정보
#
# **1주차 - Introduction**
# - python 특정
# - python 설치
# - 기본 문법
#
#
# **2주차 - python 기초 - 1**
# - if
# - while
# - for
# - 함수의 기초
#
# **3주차 - python 기초 - 2**
# - 데이터타입
# - List
# - Tuple
# - Dictionary
# - Set
#
# **4주차 - 클래스와 객체**
# - 객체
# - 클래스
#
# **5주차 - 데이터분석 - 1 Numpy **
# - 데이터 분석이란
# - numpy
# - 실습
#
# **6주차 - 데이터분석 - 2 Pandas(1)**
# - pandas
# - 실습
#
# **7주차 - 데이터분석 - 3 Pandas(2) **
# - pandas
# - 실습
#
# **8주차 - 데이터분석 - 4 Pandas(3) **
# - pandas
# - 실습
#
# **9주차 - 데이터분석 - 5 Matplotlib, 크롤링 기초**
# - Matplotlib
# - Urllib
# - Beautifulsoup4
#
# **10주차 - Final Project **
# - 자유주제로 데이터 분석 준비
#
# **11주차 - Final Project**
# - 발표

# %% [markdown]
# -------------------------
